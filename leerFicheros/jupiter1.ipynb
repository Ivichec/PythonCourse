# %%
import pandas as pd
archivo = pd.read_csv("C:\\Users\\Iván\\Documents\\Python\\leerFicheros\\usuario.csv")
archivo
# Out:
#    codigo                correo      usuario  \
# 0       1       prueba@mail.com   willmattos
# 1       2      usuario@mail.com         user
# 2       3     usuario2@mail.com     usuario2
# 3       4  nuevacuenta@mail.com  nuevacuenta
# 4       5      prueba1@mail.com         hola
#
#                                                clave  rol     recuperar  \
# 0  $2y$13$IY76RQBetyV8Wua/hvPoSOYrss2GQ8AXgbQHhRP...  2.0           NaN
# 1  $2y$13$Jua3ih.qqxHcnHMfGLnaEub5LwGsThidos.ipys...  0.0  1.402433e+09
# 2  $2y$13$Jua3ih.qqxHcnHMfGLnaEub5LwGsThidos.ipys...  1.0  1.402433e+09
# 3  $2y$13$DXO.c8DAGPJLmybQagJlVus9NIQp8aJPGz5CauU...  NaN  1.293649e+09
# 4  $2y$13$Jj/6G6.1uz3mWKipAYNXaOHmbTJf3jUI/qC0WN9...  NaN           NaN
#
#    activado      foto  bloquear
# 0       1.0  you1.jpg       NaN
# 1       1.0       NaN       NaN
# 2       1.0       NaN       NaN
# 3       NaN       NaN       NaN
# 4       1.0       NaN       NaN
